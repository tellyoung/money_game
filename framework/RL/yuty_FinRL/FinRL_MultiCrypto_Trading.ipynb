# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/3-Practical/FinRL_MultiCrypto_Trading.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Multiple Cryptocurrencies Trading Demo

# %% [markdown]
# ## Installation

# %%
# !pip install wrds
# !pip install swig
# !pip install yfinance stockstats
# !pip install alpaca_trade_api
# !pip install ray[default]
# !pip install lz4
# !pip install ray[tune]
# !pip install tensorboardX
# !pip install gputil
# !pip install trading_calendars
# !pip install wrds
# !pip install rqdatac
# !pip install sqlalchemy==1.2.19
# !pip install tushare
# !pip install TA-Lib
# !pip install baostock
# !pip install quandl
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: wrds in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (3.3.0)
# Requirement already satisfied: packaging<=24.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (24.2)
# Requirement already satisfied: pandas<2.3,>=2.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (2.2.3)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (2.9.10)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (2.0.39)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2025.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from sqlalchemy<2.1,>=2->wrds) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.17.0)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: swig in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (4.3.0)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: yfinance in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (0.2.55)
# Requirement already satisfied: stockstats in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (0.5.4)
# Requirement already satisfied: pandas>=1.3.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (2.2.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (2.2.4)
# Requirement already satisfied: requests>=2.31 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (4.3.7)
# Requirement already satisfied: pytz>=2022.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (2025.1)
# Requirement already satisfied: frozendict>=2.3.4 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (3.17.9)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from yfinance) (4.13.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.31->yfinance) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.31->yfinance) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.31->yfinance) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: alpaca_trade_api in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: pandas>=0.18.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (2.2.3)
# Requirement already satisfied: numpy>=1.11.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (2.2.4)
# Requirement already satisfied: requests<3,>2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (2.32.3)
# Requirement already satisfied: urllib3<2,>1.24 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (1.8.0)
# Requirement already satisfied: websockets<11,>=9.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (10.4)
# Requirement already satisfied: msgpack==1.0.3 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (1.0.3)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (3.11.14)
# Requirement already satisfied: PyYAML==6.0.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from alpaca_trade_api) (2.1.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from deprecation==2.1.0->alpaca_trade_api) (24.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (6.2.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca_trade_api) (1.18.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests<3,>2->alpaca_trade_api) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests<3,>2->alpaca_trade_api) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests<3,>2->alpaca_trade_api) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.18.1->alpaca_trade_api) (1.17.0)
# zsh:1: no matches found: ray[default]
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting lz4
#   Downloading https://mirrors.aliyun.com/pypi/packages/e4/94/c53de5f07c7dc11cf459aab2a1d754f5df5f693bfacbbe1e4914bfd02f1e/lz4-4.4.4-cp311-cp311-macosx_11_0_arm64.whl (189 kB)
# Installing collected packages: lz4
# Successfully installed lz4-4.4.4
# zsh:1: no matches found: ray[tune]
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: tensorboardX in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (2.6.2.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tensorboardX) (2.2.4)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tensorboardX) (24.2)
# Requirement already satisfied: protobuf>=3.20 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tensorboardX) (6.30.1)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting gputil
#   Downloading https://mirrors.aliyun.com/pypi/packages/ed/0e/5c61eedde9f6c87713e89d794f01e378cfd9565847d4576fa627d758c554/GPUtil-1.4.0.tar.gz (5.5 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: gputil
#   Building wheel for gputil (setup.py) ... done
#   Created wheel for gputil: filename=gputil-1.4.0-py3-none-any.whl size=7435 sha256=f4a7a7605cf82977b08e2de17ab6b2c77ee8b75ef7734c5e68b0ab1aa0bb9c4f
#   Stored in directory: /Users/yutieyang/Library/Caches/pip/wheels/4c/54/8d/89d650b51c5aee1a3aca220f3111da30924ee59a0ddda623f0
# Successfully built gputil
# Installing collected packages: gputil
# Successfully installed gputil-1.4.0
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting trading_calendars
#   Downloading https://mirrors.aliyun.com/pypi/packages/1e/6e/613df8268dea3aac81d3b9d9872d4e48526f8650e970ca1d14911f02dad0/trading_calendars-2.1.1.tar.gz (108 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from trading_calendars) (2.2.4)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from trading_calendars) (2.2.3)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from trading_calendars) (2.9.0.post0)
# Requirement already satisfied: pytz in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from trading_calendars) (2025.1)
# Requirement already satisfied: six in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from trading_calendars) (1.17.0)
# Requirement already satisfied: toolz in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from trading_calendars) (1.0.0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->trading_calendars) (2025.2)
# Building wheels for collected packages: trading_calendars
#   Building wheel for trading_calendars (setup.py) ... done
#   Created wheel for trading_calendars: filename=trading_calendars-2.1.1-py3-none-any.whl size=140969 sha256=e38419a88cee825ac2ac224cda6f614675e14c13776adb0aba6c36a167d0fac2
#   Stored in directory: /Users/yutieyang/Library/Caches/pip/wheels/e4/d7/0b/c1c661f33db59a305f5d1a8ed177c6a10d005f2a3b2850dd6e
# Successfully built trading_calendars
# Installing collected packages: trading_calendars
# Successfully installed trading_calendars-2.1.1
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: wrds in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (3.3.0)
# Requirement already satisfied: packaging<=24.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (24.2)
# Requirement already satisfied: pandas<2.3,>=2.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (2.2.3)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (2.9.10)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from wrds) (2.0.39)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2025.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from sqlalchemy<2.1,>=2->wrds) (4.12.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.17.0)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting rqdatac
#   Downloading https://mirrors.aliyun.com/pypi/packages/ed/9f/4f64615abd38fc7ecb7ad50ca8cd3155fb80427f816a963a5c2a8dc5622e/rqdatac-3.2.2-cp311-cp311-macosx_11_0_arm64.whl (214 kB)
# Collecting brotli (from rqdatac)
#   Downloading https://mirrors.aliyun.com/pypi/packages/96/12/ad41e7fadd5db55459c4c401842b47f7fee51068f86dd2894dd0dcfc2d2a/Brotli-1.1.0-cp311-cp311-macosx_10_9_universal2.whl (873 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.1/873.1 kB 16.7 MB/s eta 0:00:00
# Collecting zstandard (from rqdatac)
#   Downloading https://mirrors.aliyun.com/pypi/packages/e8/46/66d5b55f4d737dd6ab75851b224abf0afe5774976fe511a54d2eb9063a41/zstandard-0.23.0-cp311-cp311-macosx_11_0_arm64.whl (633 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.7/633.7 kB 12.5 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from rqdatac) (2.9.0.post0)
# Requirement already satisfied: msgpack>=0.5.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from rqdatac) (1.0.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from rqdatac) (1.17.0)
# Requirement already satisfied: pandas!=2.1.* in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from rqdatac) (2.2.3)
# Collecting orjson (from rqdatac)
#   Downloading https://mirrors.aliyun.com/pypi/packages/9e/60/a9c674ef1dd8ab22b5b10f9300e7e70444d4e3cda4b8258d6c2488c32143/orjson-3.10.18-cp311-cp311-macosx_15_0_arm64.whl (133 kB)
# Collecting python-rapidjson (from rqdatac)
#   Downloading https://mirrors.aliyun.com/pypi/packages/7a/68/d65ae2af413c5159fedcb7ce6fa491437439767e7ff0cbd4efea78395e8b/python_rapidjson-1.20-cp311-cp311-macosx_11_0_arm64.whl (210 kB)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas!=2.1.*->rqdatac) (2.2.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas!=2.1.*->rqdatac) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas!=2.1.*->rqdatac) (2025.2)
# Installing collected packages: brotli, zstandard, python-rapidjson, orjson, rqdatac
# Successfully installed brotli-1.1.0 orjson-3.10.18 python-rapidjson-1.20 rqdatac-3.2.2 zstandard-0.23.0
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting sqlalchemy==1.2.19
#   Downloading https://mirrors.aliyun.com/pypi/packages/f9/67/d07cf7ac7e6dd0bc55ba62816753f86d7c558107104ca915e730c9ec2512/SQLAlchemy-1.2.19.tar.gz (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 22.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=sqlalchemy-1.2.19-cp311-cp311-macosx_11_0_arm64.whl size=1105658 sha256=a0e1e97c946a8153cd17bd9288410e5913560095cd3ad44a53996e04c1aac960
#   Stored in directory: /Users/yutieyang/Library/Caches/pip/wheels/9e/e1/a9/acf40650b3c475853002a1e452c3cab9e23abd76f822618eae
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.39
#     Uninstalling SQLAlchemy-2.0.39:
#       Successfully uninstalled SQLAlchemy-2.0.39
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wrds 3.3.0 requires sqlalchemy<2.1,>=2, but you have sqlalchemy 1.2.19 which is incompatible.
# Successfully installed sqlalchemy-1.2.19
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: tushare in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (1.4.19)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tushare) (2.2.3)
# Requirement already satisfied: requests in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tushare) (2.32.3)
# Requirement already satisfied: lxml in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tushare) (5.3.1)
# Requirement already satisfied: simplejson in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tushare) (3.20.1)
# Requirement already satisfied: bs4 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tushare) (0.0.2)
# Requirement already satisfied: websocket-client>=0.57.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tushare) (1.8.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from tushare) (4.67.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from bs4->tushare) (4.13.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->tushare) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->tushare) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->tushare) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->tushare) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->tushare) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->tushare) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->tushare) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->tushare) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->tushare) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from beautifulsoup4->bs4->tushare) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from beautifulsoup4->bs4->tushare) (4.12.2)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: TA-Lib in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (0.6.3)
# Requirement already satisfied: setuptools in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from TA-Lib) (75.8.2)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from TA-Lib) (2.2.4)
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting baostock
#   Downloading https://mirrors.aliyun.com/pypi/packages/b2/37/bbabac2d33723d71bd8dbd5e819d9cbe5dc1e031b7dd12ed7de8fa040816/baostock-0.8.9-py3-none-any.whl (45 kB)
# Requirement already satisfied: pandas>=0.18.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from baostock) (2.2.3)
# Requirement already satisfied: numpy>=1.23.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.18.0->baostock) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.18.0->baostock) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.18.0->baostock) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.18.0->baostock) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.18.0->baostock) (1.17.0)
# Installing collected packages: baostock
# Successfully installed baostock-0.8.9
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Collecting quandl
#   Downloading https://mirrors.aliyun.com/pypi/packages/c9/cd/54ab3484243431e02dabab1254ffde296c005e0d11346536e5e02ce6c828/Quandl-3.7.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pandas>=0.14 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from quandl) (2.2.3)
# Requirement already satisfied: numpy>=1.8 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from quandl) (2.2.4)
# Requirement already satisfied: requests>=2.7.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from quandl) (2.32.3)
# Collecting inflection>=0.3.1 (from quandl)
#   Downloading https://mirrors.aliyun.com/pypi/packages/59/91/aa6bde563e0085a02a435aa99b49ef75b0a4b062635e606dab23ce18d720/inflection-0.5.1-py2.py3-none-any.whl (9.5 kB)
# Requirement already satisfied: python-dateutil in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from quandl) (2.9.0.post0)
# Requirement already satisfied: six in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from quandl) (1.17.0)
# Collecting more-itertools (from quandl)
#   Downloading https://mirrors.aliyun.com/pypi/packages/2b/9f/7ba6f94fc1e9ac3d2b853fdff3035fb2fa5afbed898c4a72b8a020610594/more_itertools-10.7.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.14->quandl) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas>=0.14->quandl) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.7.0->quandl) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.7.0->quandl) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.7.0->quandl) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests>=2.7.0->quandl) (2025.1.31)
# Installing collected packages: more-itertools, inflection, quandl
# Successfully installed inflection-0.5.1 more-itertools-10.7.0 quandl-3.7.0

# %% [markdown]
# ## Import Related Packages

# %%
# %cd /Users/yutieyang/Documents/yuty/yuty_projects/money_game/RL/FinRL-Meta
from meta.env_crypto_trading.env_multiple_crypto import CryptoEnv
# Out:
# /Users/yutieyang/Documents/yuty/yuty_projects/money_game/RL/FinRL-Meta

# %%
import ray
from ray.rllib.algorithms.a2c import A2CConfig
from ray.rllib.algorithms.a2c import A2C
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 2
#       1 import ray
# ----> 2 from ray.rllib.algorithms.a2c import A2CConfig
#       3 from ray.rllib.algorithms.a2c import A2C
#
# ModuleNotFoundError: No module named 'ray.rllib.algorithms.a2c'

# %% [markdown]
# ## Functions for Training and Testing

# %%
from ray.rllib.algorithms import a2c
from ray.rllib.algorithms.a2c import A2CConfig
from ray.rllib.algorithms.a2c import A2C
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from ray.rllib.algorithms import a2c
#       2 from ray.rllib.algorithms.a2c import A2CConfig
#       3 from ray.rllib.algorithms.a2c import A2C
#
# ImportError: cannot import name 'a2c' from 'ray.rllib.algorithms' (/opt/anaconda3/envs/finrl/lib/python3.11/site-packages/ray/rllib/algorithms/__init__.py)

# %%
from ray.rllib.algorithms.a3c import a2c
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 from ray.rllib.algorithms.a3c import a2c
#
# ModuleNotFoundError: No module named 'ray.rllib.algorithms.a3c'

# %%
from agents.rllib_models import DRLAgent as DRLAgent_rllib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from agents.rllib_models import DRLAgent as DRLAgent_rllib
#
# File ~/Documents/yuty/yuty_projects/money_game/RL/FinRL-Meta/agents/rllib_models.py:3
#       1 # DRL models from RLlib
#       2 import ray
# ----> 3 from ray.rllib.agents.a3c import a2c
#       4 from ray.rllib.agents.ddpg import ddpg
#       5 from ray.rllib.agents.ddpg import td3
#
# ModuleNotFoundError: No module named 'ray.rllib.agents'

# %%
from agents.elegantrl_models import DRLAgent as DRLAgent_erl
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from meta.data_processor import DataProcessor

def train(start_date, end_date, ticker_list, data_source, time_interval, 
          technical_indicator_list, drl_lib, env, model_name, if_vix=True,
          **kwargs):
    
    #process data using unified data processor
    DP = DataProcessor(data_source, start_date, end_date, time_interval, **kwargs)
    price_array, tech_array, turbulence_array = DP.run(ticker_list,
                                                        technical_indicator_list, 
                                                        if_vix, cache=True)

    data_config = {'price_array': price_array,
                   'tech_array': tech_array,
                   'turbulence_array': turbulence_array}

    #build environment using processed data
    env_instance = env(config=data_config)

    #read parameters and load agents
    current_working_dir = kwargs.get('current_working_dir','./'+str(model_name))

    if drl_lib == 'elegantrl':
        break_step = kwargs.get('break_step', 1e6)
        erl_params = kwargs.get('erl_params')

        agent = DRLAgent_erl(env = env,
                             price_array = price_array,
                             tech_array=tech_array,
                             turbulence_array=turbulence_array)

        model = agent.get_model(model_name, model_kwargs = erl_params)

        trained_model = agent.train_model(model=model, 
                                          cwd=current_working_dir,
                                          total_timesteps=break_step)
        
      
    elif drl_lib == 'rllib':
        total_episodes = kwargs.get('total_episodes', 100)
        rllib_params = kwargs.get('rllib_params')

        agent_rllib = DRLAgent_rllib(env = env,
                       price_array=price_array,
                       tech_array=tech_array,
                       turbulence_array=turbulence_array)

        model,model_config = agent_rllib.get_model(model_name)

        model_config['lr'] = rllib_params['lr']
        model_config['train_batch_size'] = rllib_params['train_batch_size']
        model_config['gamma'] = rllib_params['gamma']

        trained_model = agent_rllib.train_model(model=model, 
                                          model_name=model_name,
                                          model_config=model_config,
                                          total_episodes=total_episodes)
        trained_model.save(current_working_dir)
        
            
    elif drl_lib == 'stable_baselines3':
        total_timesteps = kwargs.get('total_timesteps', 1e6)
        agent_params = kwargs.get('agent_params')

        agent = DRLAgent_sb3(env = env_instance)

        model = agent.get_model(model_name, model_kwargs = agent_params)
        trained_model = agent.train_model(model=model, 
                                tb_log_name=model_name,
                                total_timesteps=total_timesteps)
        print('Training finished!')
        trained_model.save(current_working_dir)
        print('Trained model saved in ' + str(current_working_dir))
    else:
        raise ValueError('DRL library input is NOT supported. Please check.')
# Out:
# Looking in indexes: https://mirrors.aliyun.com/pypi/simple/
# Requirement already satisfied: ray[rllib] in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (2.46.0)
# Requirement already satisfied: click>=7.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (8.1.8)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (3.18.0)
# Requirement already satisfied: jsonschema in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (1.0.3)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (24.2)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (6.30.1)
# Requirement already satisfied: pyyaml in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (6.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (2.32.3)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (2.2.3)
# Requirement already satisfied: tensorboardX>=1.9 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (19.0.1)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (2025.3.0)
# Requirement already satisfied: dm-tree in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (0.1.9)
# Requirement already satisfied: gymnasium==1.0.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (1.0.0)
# Requirement already satisfied: lz4 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (4.4.4)
# Requirement already satisfied: ormsgpack==1.7.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (1.7.0)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from ray[rllib]) (1.15.2)
# Requirement already satisfied: numpy>=1.21.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from gymnasium==1.0.0->ray[rllib]) (2.2.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from gymnasium==1.0.0->ray[rllib]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from gymnasium==1.0.0->ray[rllib]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from gymnasium==1.0.0->ray[rllib]) (0.0.4)
# Requirement already satisfied: absl-py>=0.6.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from dm-tree->ray[rllib]) (2.2.0)
# Requirement already satisfied: attrs>=18.2.0 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from dm-tree->ray[rllib]) (25.3.0)
# Requirement already satisfied: wrapt>=1.11.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from dm-tree->ray[rllib]) (1.17.2)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from jsonschema->ray[rllib]) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from jsonschema->ray[rllib]) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from jsonschema->ray[rllib]) (0.23.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->ray[rllib]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->ray[rllib]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from pandas->ray[rllib]) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->ray[rllib]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->ray[rllib]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->ray[rllib]) (1.26.20)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from requests->ray[rllib]) (2025.1.31)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/finrl/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->ray[rllib]) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 4
#       1 get_ipython().run_line_magic('pip', 'install "ray[rllib]"')
#       3 from agents.elegantrl_models import DRLAgent as DRLAgent_erl
# ----> 4 from agents.rllib_models import DRLAgent as DRLAgent_rllib
#       5 from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
#       6 from meta.data_processor import DataProcessor
#
# File ~/Documents/yuty/yuty_projects/money_game/RL/FinRL-Meta/agents/rllib_models.py:3
#       1 # DRL models from RLlib
#       2 import ray
# ----> 3 from ray.rllib.agents.a3c import a2c
#       4 from ray.rllib.agents.ddpg import ddpg
#       5 from ray.rllib.agents.ddpg import td3
#
# ModuleNotFoundError: No module named 'ray.rllib.agents'

# %%
# import DRL agents
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.elegantrl_models import DRLAgent as DRLAgent_erl

# import data processor
from meta.data_processor import DataProcessor

def test(start_date, end_date, ticker_list, data_source, time_interval,
            technical_indicator_list, drl_lib, env, model_name, if_vix=True,
            **kwargs):
  
    #process data using unified data processor
    DP = DataProcessor(data_source, start_date, end_date, time_interval, **kwargs)
    price_array, tech_array, turbulence_array = DP.run(ticker_list,
                                                        technical_indicator_list, 
                                                        if_vix, cache=True)
    
    
    np.save('./price_array.npy', price_array)
    data_config = {'price_array':price_array,
                   'tech_array':tech_array,
                   'turbulence_array':turbulence_array}
    #build environment using processed data
    env_instance = env(config=data_config)

    env_config = {
        "price_array": price_array,
        "tech_array": tech_array,
        "turbulence_array": turbulence_array,
        "if_train": False,
    }
    env_instance = env(config=env_config)

    # load elegantrl needs state dim, action dim and net dim
    net_dimension = kwargs.get("net_dimension", 2 ** 7)
    current_working_dir = kwargs.get("current_working_dir", "./" + str(model_name))
    print("price_array: ", len(price_array))

    if drl_lib == "elegantrl":
        episode_total_assets = DRLAgent_erl.DRL_prediction(
            model_name=model_name,
            cwd=current_working_dir,
            net_dimension=net_dimension,
            environment=env_instance,
        )

        return episode_total_assets

    elif drl_lib == "rllib":
        # load agent
        episode_total_assets = DRLAgent_rllib.DRL_prediction(
            model_name=model_name,
            env=env,
            price_array=price_array,
            tech_array=tech_array,
            turbulence_array=turbulence_array,
            agent_path=current_working_dir,
        )

        return episode_total_assets

    elif drl_lib == "stable_baselines3":
        episode_total_assets = DRLAgent_sb3.DRL_prediction_load_from_file(
            model_name=model_name, environment=env_instance, cwd=current_working_dir
        )

        return episode_total_assets
    else:
        raise ValueError("DRL library input is NOT supported. Please check.")

# %% [markdown]
# ## Multiple Cryptocurrencies Trading Env

# %%
import numpy as np
import math

class CryptoEnv:  # custom env
    def __init__(self, config, lookback=1, initial_capital=1e6, 
                 buy_cost_pct=1e-3, sell_cost_pct=1e-3, gamma=0.99):
        self.lookback = lookback
        self.initial_total_asset = initial_capital
        self.initial_cash = initial_capital
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.max_stock = 1
        self.gamma = gamma
        self.price_array = config['price_array']
        self.tech_array = config['tech_array']
        self._generate_action_normalizer()
        self.crypto_num = self.price_array.shape[1]
        self.max_step = self.price_array.shape[0] - lookback - 1
        
        # reset
        self.time = lookback-1
        self.cash = self.initial_cash
        self.current_price = self.price_array[self.time]
        self.current_tech = self.tech_array[self.time]
        self.stocks = np.zeros(self.crypto_num, dtype=np.float32)

        self.total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        self.episode_return = 0.0  
        self.gamma_return = 0.0
        

        '''env information'''
        self.env_name = 'MulticryptoEnv'
        self.state_dim = 1 + (self.price_array.shape[1] + self.tech_array.shape[1])*lookback
        self.action_dim = self.price_array.shape[1]
        self.if_discrete = False
        self.target_return = 10


    def reset(self) -> np.ndarray:
        self.time = self.lookback-1
        self.current_price = self.price_array[self.time]
        self.current_tech = self.tech_array[self.time]
        self.cash = self.initial_cash  # reset()
        self.stocks = np.zeros(self.crypto_num, dtype=np.float32)
        self.total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        
        state = self.get_state()
        return state

    def step(self, actions) -> (np.ndarray, float, bool, None):
        self.time += 1
        
        price = self.price_array[self.time]
        for i in range(self.action_dim):
            norm_vector_i = self.action_norm_vector[i]
            actions[i] = actions[i] * norm_vector_i
            
        for index in np.where(actions < 0)[0]:  # sell_index:
            if price[index] > 0:  # Sell only if current asset is > 0
                sell_num_shares = min(self.stocks[index], -actions[index])
                self.stocks[index] -= sell_num_shares
                self.cash += price[index] * sell_num_shares * (1 - self.sell_cost_pct)
                
        for index in np.where(actions > 0)[0]:  # buy_index:
            if price[index] > 0:  # Buy only if the price is > 0 (no missing data in this particular date)
                buy_num_shares = min(self.cash // price[index], actions[index])
                self.stocks[index] += buy_num_shares
                self.cash -= price[index] * buy_num_shares * (1 + self.buy_cost_pct)

        """update time"""
        done = self.time == self.max_step
        state = self.get_state()
        next_total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        reward = (next_total_asset - self.total_asset) * 2 ** -16  
        self.total_asset = next_total_asset
        self.gamma_return = self.gamma_return * self.gamma + reward 
        self.cumu_return = self.total_asset / self.initial_cash
        if done:
            reward = self.gamma_return
            self.episode_return = self.total_asset / self.initial_cash
        return state, reward, done, None

    def get_state(self):
        state =  np.hstack((self.cash * 2 ** -18, self.stocks * 2 ** -3))
        for i in range(self.lookback):
            tech_i = self.tech_array[self.time-i]
            normalized_tech_i = tech_i * 2 ** -15
            state = np.hstack((state, normalized_tech_i)).astype(np.float32)
        return state
    
    def close(self):
        pass

    def _generate_action_normalizer(self):
        action_norm_vector = []
        price_0 = self.price_array[0]
        for price in price_0:
            x = math.floor(math.log(price, 10)) #the order of magnitude 
            action_norm_vector.append(1/((10)**x)) 
            
        action_norm_vector = np.asarray(action_norm_vector) * 10000
        self.action_norm_vector = np.asarray(action_norm_vector)

# %% [markdown]
# ## Set Parameters

# %%
TICKER_LIST = ['BTCUSDT','ETHUSDT','ADAUSDT','BNBUSDT','XRPUSDT',
                'SOLUSDT','DOTUSDT', 'DOGEUSDT','AVAXUSDT','UNIUSDT']
env = CryptoEnv
TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2021-09-02'

TEST_START_DATE = '2021-09-21'
TEST_END_DATE = '2021-09-30'

INDICATORS = ['macd', 'rsi', 'cci', 'dx'] #self-defined technical indicator list is NOT supported yet

ERL_PARAMS = {"learning_rate": 2**-15,"batch_size": 2**11,
                "gamma": 0.99, "seed":312,"net_dimension": 2**9, 
                "target_step": 5000, "eval_gap": 30, "eval_times": 1}

# %% [markdown]
# ## Training

# %%
train(start_date=TRAIN_START_DATE, 
      end_date=TRAIN_END_DATE,
      ticker_list=TICKER_LIST, 
      data_source='binance',
      time_interval='5m', 
      technical_indicator_list=INDICATORS,
      drl_lib='elegantrl', 
      env=env, 
      model_name='ppo', 
      current_working_dir='./test_ppo',
      erl_params=ERL_PARAMS,
      break_step=5e4,
      if_vix=False
      )
# Out:
# binance successfully connected
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# Successfully transformed into array
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-c3f95f8e0ccd> in <module>()
#      11       erl_params=ERL_PARAMS,
#      12       break_step=5e4,
# ---> 13       if_vix=False
#      14       )
#
# <ipython-input-4-c2f4f1f1ce9a> in train(start_date, end_date, ticker_list, data_source, time_interval, technical_indicator_list, drl_lib, env, model_name, if_vix, **kwargs)
#      33                              turbulence_array=turbulence_array)
#      34
# ---> 35         model = agent.get_model(model_name, model_kwargs = erl_params)
#      36
#      37         trained_model = agent.train_model(model=model,
#
# /FinRL-Meta/agents/elegantrl_models.py in get_model(self, model_name, model_kwargs)
#      56         if model_name not in MODELS:
#      57             raise NotImplementedError("NotImplementedError")
# ---> 58         model = Arguments(agent=agent, env=env)
#      59         model.if_off_policy = model_name in OFF_POLICY_MODELS
#      60         if model_kwargs is not None:
#
# TypeError: __init__() got an unexpected keyword argument 'agent'

# %% [markdown]
# ## Testing

# %%
account_value_erl = test(start_date = TEST_START_DATE, 
                        end_date = TEST_END_DATE,
                        ticker_list = TICKER_LIST, 
                        data_source = 'binance',
                        time_interval= '5m', 
                        technical_indicator_list= INDICATORS,
                        drl_lib='elegantrl', 
                        env=env, 
                        model_name='ppo', 
                        current_working_dir='./test_ppo', 
                        net_dimension = 2**9, 
                        if_vix=False
                        )

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
# %matplotlib inline
#calculate agent returns
account_value_erl = np.array(account_value_erl)
agent_returns = account_value_erl/account_value_erl[0]
#calculate buy-and-hold btc returns
price_array = np.load('./price_array.npy')
btc_prices = price_array[:,0]
buy_hold_btc_returns = btc_prices/btc_prices[0]
#calculate equal weight portfolio returns
price_array = np.load('./price_array.npy')
initial_prices = price_array[0,:]
equal_weight = np.array([1e5/initial_prices[i] for i in range(len(TICKER_LIST))])
equal_weight_values = []
for i in range(0, price_array.shape[0]):
    equal_weight_values.append(np.sum(equal_weight * price_array[i]))
equal_weight_values = np.array(equal_weight_values)
equal_returns = equal_weight_values/equal_weight_values[0]
#plot 
plt.figure(dpi=200)
plt.grid()
plt.grid(which='minor', axis='y')
plt.title('Cryptocurrency Trading ', fontsize=20)
plt.plot(agent_returns, label='ElegantRL Agent', color = 'red')
plt.plot(buy_hold_btc_returns, label='Buy-and-Hold BTC', color='blue')
plt.plot(equal_returns, label='Equal Weight Portfolio', color='green')
plt.ylabel('Return', fontsize=16)
plt.xlabel('Times (5min)', fontsize=16)
plt.xticks(size=14)
plt.yticks(size=14)
'''ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(210))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(21))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.005))
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=2))
ax.xaxis.set_major_formatter(ticker.FixedFormatter([]))'''
plt.legend(fontsize=10.5)
