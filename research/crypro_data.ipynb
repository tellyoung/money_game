# %%
# # download from https://api.coingecko.com/api/v3/
# python collector.py download_data --source_dir /Users/yutieyang/Documents/yuty/yuty_projects/money_game/Data/qlib/crypto_data/source/1d --start 2025-05-01 --end 2025-5-30 --delay 1 --interval 1d

# # normalize
# python collector.py normalize_data --source_dir /Users/yutieyang/Documents/yuty/yuty_projects/money_game/Data/qlib/crypto_data/source/1d --normalize_dir /Users/yutieyang/Documents/yuty/yuty_projects/money_game/Data/qlib/crypto_data/source/1d_nor --interval 1d --date_field_name date

# # dump data
# cd qlib/scripts
# python dump_bin.py dump_all --csv_path /Users/yutieyang/Documents/yuty/yuty_projects/money_game/Data/qlib/crypto_data/source/1d_nor --qlib_dir /Users/yutieyang/Documents/yuty/yuty_projects/money_game/Data/qlib/crypto_data --freq day --date_field_name date --include_fields prices,total_volumes,market_caps
