# %%
import pandas as pd

data = pd.read_feather("/Users/yutieyang/Documents/yuty/yuty_projects/money_game/Trading/factor_mining/factor_data/factor_data.feather")  # 读取Feather格式数据
data.head()
# Out:
#                        date      open      high       low     close    volume  \
# 0 2025-01-01 00:00:00+00:00  93576.00  93702.15  93537.50  93661.20  45.94160
# 1 2025-01-01 00:05:00+00:00  93661.20  93678.02  93600.00  93607.10  71.94585
# 2 2025-01-01 00:10:00+00:00  93607.10  93656.19  93489.03  93656.18  57.96928
# 3 2025-01-01 00:15:00+00:00  93656.19  93840.05  93614.95  93796.35  39.74456
# 4 2025-01-01 00:20:00+00:00  93796.35  93898.05  93707.81  93740.00  38.38053
#
#    RandomFactor_1  RandomFactor_2  RandomFactor_3  RandomFactor_4  ...  \
# 0             NaN             NaN             NaN             NaN  ...
# 1             NaN             NaN             NaN             NaN  ...
# 2             NaN         93576.0             NaN             NaN  ...
# 3             NaN         93661.2        0.001443             NaN  ...
# 4             NaN         93607.1        0.001420             NaN  ...
#
# ...
